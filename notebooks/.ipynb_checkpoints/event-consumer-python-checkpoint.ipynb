# %% [markdown]
# # Install Libraries (if needed)

# %%
#!pip install sseclient

# %%
#!pip install kafka-python

# %%
# References: https://wikitech.wikimedia.org/wiki/Event_Platform/EventStreams
import json
from sseclient import SSEClient as EventSource
from kafka import KafkaConsumer

# Create consumer
consumer = KafkaConsumer(bootstrap_servers='kafka-server:9092', #Kafka server
                        auto_offset_reset='earliest', #Consume messages from the beggining
                        value_deserializer=lambda m: json.loads(m.decode('utf-8'))) #json deserializer

consumer.subscribe(['wiki-changes']) #kafka topic

for message in consumer:
    print("**************************************")
    print("**************************************")
    print("**************************************")
    print(message)
# Out:
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=0, timestamp=1592991287275, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/File:SLM_POR55-3899_-_Nyk%C3%B6pings_Automobilfabrik_%C3%A5r_1955.jpg', 'request_id': '666e2ca0-065e-4087-b302-307b35f9ecb6', 'id': 'f9f1a82b-533f-4b5a-ae20-b746d203949e', 'dt': '2020-06-24T09:34:46Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103706}, 'id': 1406889548, 'type': 'edit', 'namespace': 6, 'title': 'File:SLM POR55-3899 - Nyköpings Automobilfabrik år 1955.jpg', 'comment': 'added [[Category:Scanned with Microtek ScanMaker 9800XL Plus]]', 'timestamp': 1592991286, 'user': 'BotAdventures', 'bot': True, 'minor': True, 'patrolled': True, 'length': {'old': 677, 'new': 734}, 'revision': {'old': 428575543, 'new': 428595943}, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': 'added <a href="/wiki/Category:Scanned_with_Microtek_ScanMaker_9800XL_Plus" title="Category:Scanned with Microtek ScanMaker 9800XL Plus">Category:Scanned with Microtek ScanMaker 9800XL Plus</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1196, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1, timestamp=1592991287279, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://de.wikipedia.org/wiki/ISO_7010', 'request_id': '1645ec5e-873c-4e5d-831e-73d20b6edb8b', 'id': '362992bf-c0e9-4141-b1bb-f3646dcc27cd', 'dt': '2020-06-24T09:34:46Z', 'domain': 'de.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103707}, 'id': 291840120, 'type': 'edit', 'namespace': 0, 'title': 'ISO 7010', 'comment': '', 'timestamp': 1592991286, 'user': 'Tom md', 'bot': False, 'minor': False, 'length': {'old': 11828, 'new': 11833}, 'revision': {'old': 200732252, 'new': 201260275}, 'server_url': 'https://de.wikipedia.org', 'server_name': 'de.wikipedia.org', 'server_script_path': '/w', 'wiki': 'dewiki', 'parsedcomment': ''}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=770, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=2, timestamp=1592991287304, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q43277247', 'request_id': '5aa832ac-09a4-4051-a60d-d8d4acdd218f', 'id': '50c0e332-69d5-45b8-88f0-9ddc89ff7a59', 'dt': '2020-06-24T09:34:46Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103708}, 'id': 1254672706, 'type': 'edit', 'namespace': 0, 'title': 'Q43277247', 'comment': '/* wbremoveclaims-remove:1| */ [[Property:P54]]: [[Q2349328]]', 'timestamp': 1592991286, 'user': 'Lidor.binyamin', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 18796, 'new': 18382}, 'revision': {'old': 1215411702, 'new': 1215411711}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200f<span dir="auto"><span class="autocomment">הוסרה טענה אחת: </span></span> <a href="/wiki/Property:P54" title="Property:P54">Property:P54</a>: <a href="/wiki/Q2349328" title="Q2349328">Q2349328</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1143, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=3, timestamp=1592991287349, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q36921', 'request_id': '160fda34-3b94-4a07-8394-3f1ae0a9861a', 'id': 'ba93ce28-de1b-4fa1-bb76-00766e0dbddb', 'dt': '2020-06-24T09:34:47Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103709}, 'type': 'log', 'namespace': 0, 'title': 'Q36921', 'comment': '', 'timestamp': 1592991287, 'user': '62.2.208.206', 'bot': False, 'log_id': 0, 'log_type': 'abusefilter', 'log_action': 'hit', 'log_params': {'action': 'edit', 'filter': 18, 'actions': 'warn', 'log': 13943596}, 'log_action_comment': '62.2.208.206 triggered [[Special:AbuseFilter/18|filter 18]], performing the action "edit" on [[Q36921]]. Actions taken: Warnen ([[Special:AbuseLog/13943596|details]])', 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': ''}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=993, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=4, timestamp=1592991287349, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q36921', 'request_id': '160fda34-3b94-4a07-8394-3f1ae0a9861a', 'id': '11d39f77-7ed9-4727-91ad-ff639fc697e6', 'dt': '2020-06-24T09:34:47Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103710}, 'type': 'log', 'namespace': 0, 'title': 'Q36921', 'comment': '', 'timestamp': 1592991287, 'user': '62.2.208.206', 'bot': False, 'log_id': 0, 'log_type': 'abusefilter', 'log_action': 'hit', 'log_params': {'action': 'edit', 'filter': 'global-201', 'actions': '', 'log': 13943597}, 'log_action_comment': '62.2.208.206 triggered [[Special:AbuseFilter/global-201|filter global-201]], performing the action "edit" on [[Q36921]]. Actions taken: none ([[Special:AbuseLog/13943597|details]])', 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': ''}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1013, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=5, timestamp=1592991287463, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wikipedia.org/wiki/Avera_Health', 'request_id': 'a9254a7c-70fe-4f65-a09c-c379051d3abb', 'id': 'c909b55a-76b2-458b-8e34-9bf65b2c5e16', 'dt': '2020-06-24T09:34:45Z', 'domain': 'en.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103711}, 'id': 1275010931, 'type': 'edit', 'namespace': 0, 'title': 'Avera Health', 'comment': 'cleanup promotional material, esp. unsourced & empty [[WP:PUFFERY]] claims; moved long list of locations to bottom', 'timestamp': 1592991285, 'user': 'Whisperjanes', 'bot': False, 'minor': False, 'length': {'old': 14770, 'new': 13902}, 'revision': {'old': 964232680, 'new': 964234134}, 'server_url': 'https://en.wikipedia.org', 'server_name': 'en.wikipedia.org', 'server_script_path': '/w', 'wiki': 'enwiki', 'parsedcomment': 'cleanup promotional material, esp. unsourced &amp; empty <a href="/wiki/Wikipedia:PUFFERY" class="mw-redirect" title="Wikipedia:PUFFERY">WP:PUFFERY</a> claims; moved long list of locations to bottom'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1103, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=6, timestamp=1592991287490, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q41206407', 'request_id': 'be2b0cb6-946b-4d42-838c-456ab5e72a03', 'id': 'c406f622-7cee-4002-9d3e-aa2e247bf594', 'dt': '2020-06-24T09:34:46Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103712}, 'id': 1254672707, 'type': 'edit', 'namespace': 0, 'title': 'Q41206407', 'comment': '/* wbeditentity-update-languages-short:0||nl */ nl-description, [[User:Edoderoobot/Set-nl-description|python code]] - person', 'timestamp': 1592991286, 'user': 'Edoderoobot', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 5967, 'new': 6053}, 'revision': {'old': 1116095659, 'new': 1215411712}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Changed label, description and/or aliases in nl: </span></span> nl-description, <a href="/wiki/User:Edoderoobot/Set-nl-description" title="User:Edoderoobot/Set-nl-description">python code</a> - person'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1183, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=7, timestamp=1592991287509, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/File:De-projektier.ogg', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': 'b6ce864a-6a41-41ca-ab6d-a4c41a96a315', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103713}, 'id': 1406889549, 'type': 'log', 'namespace': 6, 'title': 'File:De-projektier.ogg', 'comment': 'VicuñaUploader 1.23', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'log_id': 296267564, 'log_type': 'upload', 'log_action': 'upload', 'log_params': {'img_sha1': 'dbyh94o02nrpaws8bqfxsyz9imthp38', 'img_timestamp': '20200624093445'}, 'log_action_comment': 'uploaded &quot;[[File:De-projektier.ogg]]&quot;: VicuñaUploader 1.23', 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': 'VicuñaUploader 1.23'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1029, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=8, timestamp=1592991287701, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/File:Curso_Alto_Manzanares.JPG', 'request_id': 'ab5962a2-3ed2-416a-9078-2bea747f976a', 'id': '942e7110-e11b-4d79-a1c5-2c563181d442', 'dt': '2020-06-24T09:34:46Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103714}, 'id': 1406889550, 'type': 'edit', 'namespace': 6, 'title': 'File:Curso Alto Manzanares.JPG', 'comment': '/* wbeditentity-update:0| */ SDC: added [[d:Special:EntityPage/P180]] => [[d:Special:EntityPage/Q16512]]', 'timestamp': 1592991286, 'user': 'Strakhov', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 3884, 'new': 4312}, 'revision': {'old': 398147961, 'new': 428595944}, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Changed an entity: </span></span> SDC: added <a href="https://www.wikidata.org/wiki/Special:EntityPage/P180" class="extiw" title="d:Special:EntityPage/P180">d:Special:EntityPage/P180</a> =&gt; <a href="https://www.wikidata.org/wiki/Special:EntityPage/Q16512" class="extiw" title="d:Special:EntityPage/Q16512">d:Special:EntityPage/Q16512</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1368, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=9, timestamp=1592991287855, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q96621391', 'request_id': '7c9008d7-a867-4d3f-b2c2-48be8f9a21b9', 'id': '48407a86-975d-4a3e-9f61-d4eb19a95a21', 'dt': '2020-06-24T09:34:47Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103715}, 'id': 1254672708, 'type': 'edit', 'namespace': 0, 'title': 'Q96621391', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P108]]: [[Q319239]]', 'timestamp': 1592991287, 'user': 'Batraveh', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 2562, 'new': 3383}, 'revision': {'old': 1215411654, 'new': 1215411713}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Created claim: </span></span> <a href="/wiki/Property:P108" title="Property:P108">Property:P108</a>: <a href="/wiki/Q319239" title="Q319239">Q319239</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1072, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=10, timestamp=1592991287886, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:Scanned_with_Microtek_ScanMaker_9800XL_Plus', 'request_id': '666e2ca0-065e-4087-b302-307b35f9ecb6', 'id': 'b44634da-feb5-4c5e-9573-177d941dcdda', 'dt': '2020-06-24T09:34:46Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103716}, 'id': 1406889551, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Scanned with Microtek ScanMaker 9800XL Plus', 'comment': '[[:File:SLM POR55-3899 - Nyköpings Automobilfabrik år 1955.jpg]] added to category', 'timestamp': 1592991286, 'user': 'BotAdventures', 'bot': True, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:SLM_POR55-3899_-_Nyk%C3%B6pings_Automobilfabrik_%C3%A5r_1955.jpg" title="File:SLM POR55-3899 - Nyköpings Automobilfabrik år 1955.jpg">File:SLM POR55-3899 - Nyköpings Automobilfabrik år 1955.jpg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1142, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=11, timestamp=1592991287887, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://nn.wikipedia.org/wiki/Varangerhalv%C3%B8ya', 'request_id': '6e1c4f2c-d960-4d55-8173-c645fb18bb98', 'id': 'f5f3110b-09fc-4851-bea6-166c77dc6044', 'dt': '2020-06-24T09:34:46Z', 'domain': 'nn.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103717}, 'id': 11235309, 'type': 'edit', 'namespace': 0, 'title': 'Varangerhalvøya', 'comment': '/* Geografi */', 'timestamp': 1592991286, 'user': 'Sju hav', 'bot': False, 'minor': True, 'patrolled': False, 'length': {'old': 4943, 'new': 4960}, 'revision': {'old': 3249542, 'new': 3249543}, 'server_url': 'https://nn.wikipedia.org', 'server_name': 'nn.wikipedia.org', 'server_script_path': '/w', 'wiki': 'nnwiki', 'parsedcomment': '<span dir="auto"><span class="autocomment"><a href="/wiki/Varangerhalv%C3%B8ya#Geografi" title="Varangerhalvøya">→\u200eGeografi</a></span></span>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=985, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=12, timestamp=1592991287941, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:CC-BY-SA-4.0', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': '2bbc1374-1355-499c-9d17-2fab9e7e36d9', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103718}, 'id': 1406889552, 'type': 'categorize', 'namespace': 14, 'title': 'Category:CC-BY-SA-4.0', 'comment': '[[:File:De-projektier.ogg]] added to category', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:De-projektier.ogg" title="File:De-projektier.ogg">File:De-projektier.ogg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=886, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=13, timestamp=1592991287952, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:Supported_by_Wikimedia_Deutschland', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': '41478c08-f04f-497c-9f15-8401b2eb9a1a', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103719}, 'id': 1406889553, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Supported by Wikimedia Deutschland', 'comment': '[[:File:De-projektier.ogg]] added to category', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:De-projektier.ogg" title="File:De-projektier.ogg">File:De-projektier.ogg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=930, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=14, timestamp=1592991287958, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:German_pronunciation_of_verb_flections', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': '248bc8ac-a875-4b5f-9e5e-86b0abdb3242', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103720}, 'id': 1406889554, 'type': 'categorize', 'namespace': 14, 'title': 'Category:German pronunciation of verb flections', 'comment': '[[:File:De-projektier.ogg]] added to category', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:De-projektier.ogg" title="File:De-projektier.ogg">File:De-projektier.ogg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=938, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=15, timestamp=1592991287966, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q79744844', 'request_id': 'f7414813-1b25-471b-bc12-bd6e447e333a', 'id': 'a8992788-555f-476d-a973-64b0de51ba93', 'dt': '2020-06-24T09:34:47Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103721}, 'id': 1254672709, 'type': 'edit', 'namespace': 0, 'title': 'Q79744844', 'comment': '/* wbsetdescription-add:1|hy */ բադմինտոնի առաջնություններ, based on en:badminton championships', 'timestamp': 1592991287, 'user': 'ԱշբոտՏՆՂ', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 8427, 'new': 8537}, 'revision': {'old': 1181150371, 'new': 1215411714}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Added [hy] description: </span></span> բադմինտոնի առաջնություններ, based on en:badminton championships'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1339, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=16, timestamp=1592991287971, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:Audio_files_made_using_a_Rode_NT-USB_(supported_by_Wikimedia_Deutschland)', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': '51c6262b-2083-4753-b650-39f3868cdc49', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103722}, 'id': 1406889555, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Audio files made using a Rode NT-USB (supported by Wikimedia Deutschland)', 'comment': '[[:File:De-projektier.ogg]] added to category', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:De-projektier.ogg" title="File:De-projektier.ogg">File:De-projektier.ogg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1008, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=17, timestamp=1592991287975, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:Audio_files_made_by_jeuwre', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': '05bc0126-f4f7-4dcd-97bb-be2d1504bde6', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103723}, 'id': 1406889556, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Audio files made by jeuwre', 'comment': '[[:File:De-projektier.ogg]] added to category', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:De-projektier.ogg" title="File:De-projektier.ogg">File:De-projektier.ogg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=914, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=18, timestamp=1592991287984, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:Created_with_Audacity', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': '9edadf3d-32e3-491e-9708-4a16fc035e82', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103724}, 'id': 1406889557, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Created with Audacity', 'comment': '[[:File:De-projektier.ogg]] added to category', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:De-projektier.ogg" title="File:De-projektier.ogg">File:De-projektier.ogg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=904, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=19, timestamp=1592991288048, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q26991818', 'request_id': '30d8f1a4-c9c6-4f75-8fb4-de1e67bd4d4c', 'id': '59d36b1d-329a-4b75-8c73-a60f4c476abc', 'dt': '2020-06-24T09:34:47Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103725}, 'id': 1254672710, 'type': 'edit', 'namespace': 0, 'title': 'Q26991818', 'comment': '/* wbsetreference-add:2| */ [[Property:P921]]: [[Q1142806]], #quickstatements; #temporary_batch_1592991182670', 'timestamp': 1592991287, 'user': 'Charles Matthews', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 30801, 'new': 31644}, 'revision': {'old': 1215411683, 'new': 1215411715}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Added reference to claim: </span></span> <a href="/wiki/Property:P921" title="Property:P921">Property:P921</a>: <a href="/wiki/Q1142806" title="Q1142806">Q1142806</a>, #quickstatements; #temporary_batch_1592991182670'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1196, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=20, timestamp=1592991288057, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/Category:Uploaded_with_Vicu%C3%B1aUploader', 'request_id': '78661460-5ce8-474b-8e7b-6ac2c28757cb', 'id': '72909519-110e-49b7-aa77-c1f0a95925cd', 'dt': '2020-06-24T09:34:45Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103726}, 'id': 1406889558, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Uploaded with VicuñaUploader', 'comment': '[[:File:De-projektier.ogg]] added to category', 'timestamp': 1592991285, 'user': 'Jeuwre', 'bot': False, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '<a href="/wiki/File:De-projektier.ogg" title="File:De-projektier.ogg">File:De-projektier.ogg</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=928, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=21, timestamp=1592991288068, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://mr.wikipedia.org/wiki/%E0%A4%85%E0%A4%81%E0%A4%A1%E0%A5%8D%E0%A4%B0%E0%A5%82_%E0%A4%9C%E0%A5%89%E0%A4%A8%E0%A5%8D%E0%A4%B8%E0%A4%A8', 'request_id': 'e7d9cfef-b092-4bbf-a8cc-3e02980fe665', 'id': '185adb98-7b1f-4129-80e0-e26678139863', 'dt': '2020-06-24T09:34:47Z', 'domain': 'mr.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103727}, 'id': 4072255, 'type': 'edit', 'namespace': 0, 'title': 'अँड्रू जॉन्सन', 'comment': 'Bot: Fixing double redirect to [[ॲन्ड्\u200cर्\u200dयू जॉन्सन]]', 'timestamp': 1592991287, 'user': 'EmausBot', 'bot': True, 'minor': True, 'length': {'old': 100, 'new': 97}, 'revision': {'old': 1406005, 'new': 1797735}, 'server_url': 'https://mr.wikipedia.org', 'server_name': 'mr.wikipedia.org', 'server_script_path': '/w', 'wiki': 'mrwiki', 'parsedcomment': 'Bot: Fixing double redirect to <a href="/wiki/%E0%A5%B2%E0%A4%A8%E0%A5%8D%E0%A4%A1%E0%A5%8D%E2%80%8C%E0%A4%B0%E0%A5%8D%E2%80%8D%E0%A4%AF%E0%A5%82_%E0%A4%9C%E0%A5%89%E0%A4%A8%E0%A5%8D%E0%A4%B8%E0%A4%A8" title="ॲन्ड्\u200cर्\u200dयू जॉन्सन">ॲन्ड्\u200cर्\u200dयू जॉन्सन</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1488, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=22, timestamp=1592991288177, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://arz.wikipedia.org/wiki/LEDA_1212756_(%D9%85%D8%AC%D8%B1%D9%87)', 'request_id': 'be0e8b98-b1b2-410c-bcd0-1a6590f6cf91', 'id': 'd14ff07d-6912-42d0-8506-e1547f45e210', 'dt': '2020-06-24T09:34:41Z', 'domain': 'arz.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103728}, 'id': 11577087, 'type': 'edit', 'namespace': 0, 'title': 'LEDA 1212756 (مجره)', 'comment': 'بوت: تغييرات تجميلية', 'timestamp': 1592991281, 'user': 'MenoBot', 'bot': True, 'minor': True, 'length': {'old': 2853, 'new': 2857}, 'revision': {'old': 2606525, 'new': 2614119}, 'server_url': 'https://arz.wikipedia.org', 'server_name': 'arz.wikipedia.org', 'server_script_path': '/w', 'wiki': 'arzwiki', 'parsedcomment': 'بوت: تغييرات تجميلية'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1039, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=23, timestamp=1592991288213, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements', 'request_id': 'a9254a7c-70fe-4f65-a09c-c379051d3abb', 'id': 'a18dea9a-2ecf-4b2f-abb5-dd3e73a3425e', 'dt': '2020-06-24T09:34:45Z', 'domain': 'en.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103729}, 'id': 1275010932, 'type': 'categorize', 'namespace': 14, 'title': 'Category:All articles with unsourced statements', 'comment': '[[:Avera Health]] added to category, [[Special:WhatLinksHere/Avera Health|this page is included within other pages]]', 'timestamp': 1592991285, 'user': 'Whisperjanes', 'bot': False, 'server_url': 'https://en.wikipedia.org', 'server_name': 'en.wikipedia.org', 'server_script_path': '/w', 'wiki': 'enwiki', 'parsedcomment': '<a href="/wiki/Avera_Health" title="Avera Health">Avera Health</a> added to category, <a href="/wiki/Special:WhatLinksHere/Avera_Health" title="Special:WhatLinksHere/Avera Health">this page is included within other pages</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1104, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=24, timestamp=1592991288225, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_June_2020', 'request_id': 'a9254a7c-70fe-4f65-a09c-c379051d3abb', 'id': '198c9ece-1ccf-4351-bad8-544cc5cf7795', 'dt': '2020-06-24T09:34:45Z', 'domain': 'en.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103730}, 'id': 1275010933, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Articles with unsourced statements from June 2020', 'comment': '[[:Avera Health]] added to category, [[Special:WhatLinksHere/Avera Health|this page is included within other pages]]', 'timestamp': 1592991285, 'user': 'Whisperjanes', 'bot': False, 'server_url': 'https://en.wikipedia.org', 'server_name': 'en.wikipedia.org', 'server_script_path': '/w', 'wiki': 'enwiki', 'parsedcomment': '<a href="/wiki/Avera_Health" title="Avera Health">Avera Health</a> added to category, <a href="/wiki/Special:WhatLinksHere/Avera_Health" title="Special:WhatLinksHere/Avera Health">this page is included within other pages</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1126, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=25, timestamp=1592991288300, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://ru.wikinews.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8:%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%91%D0%B0%D1%80%D1%82%D0%BE%D0%BD%D1%8C', 'request_id': 'd86dc902-3fbe-4884-8ce2-673fdd075829', 'id': '68343613-4993-476a-8058-bc80eed6cb7d', 'dt': '2020-06-24T09:34:47Z', 'domain': 'ru.wikinews.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103731}, 'id': 13308590, 'type': 'new', 'namespace': 4, 'title': 'Викиновости:Статистика страниц/Категория:Бартонь', 'comment': 'Автоматическое создание страницы.', 'timestamp': 1592991287, 'user': 'NewsBots', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'new': 75}, 'revision': {'new': 4462616}, 'server_url': 'https://ru.wikinews.org', 'server_name': 'ru.wikinews.org', 'server_script_path': '/w', 'wiki': 'ruwikinews', 'parsedcomment': 'Автоматическое создание страницы.'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1637, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=26, timestamp=1592991288306, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://it.wikipedia.org/wiki/Randy_Orton', 'request_id': '43cf57de-e797-4a6e-aa5e-5f630e075d0e', 'id': '03a3cbcf-018f-4ba4-a511-aa0f2d4a36a9', 'dt': '2020-06-24T09:34:47Z', 'domain': 'it.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103732}, 'id': 274025484, 'type': 'edit', 'namespace': 0, 'title': 'Randy Orton', 'comment': 'Annullata la modifica 113739719 di [[Special:Contributions/95.244.200.235|95.244.200.235]] ([[User talk:95.244.200.235|discussione]]) ripristino modifiche originali', 'timestamp': 1592991287, 'user': 'CorranHorn7', 'bot': False, 'minor': False, 'patrolled': False, 'length': {'old': 122039, 'new': 122961}, 'revision': {'old': 113884201, 'new': 113884207}, 'server_url': 'https://it.wikipedia.org', 'server_name': 'it.wikipedia.org', 'server_script_path': '/w', 'wiki': 'itwiki', 'parsedcomment': 'Annullata la modifica 113739719 di <a href="/wiki/Speciale:Contributi/95.244.200.235" title="Speciale:Contributi/95.244.200.235">95.244.200.235</a> (<a href="/wiki/Discussioni_utente:95.244.200.235" title="Discussioni utente:95.244.200.235">discussione</a>) ripristino modifiche originali'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1263, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=27, timestamp=1592991288577, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wikipedia.org/wiki/Divyaa_Unni', 'request_id': '7bafeb5a-bddc-4ba5-938c-a401e100f2dc', 'id': '0e5aceaa-b3b0-4ebf-b91e-37b4921b97ec', 'dt': '2020-06-24T09:34:47Z', 'domain': 'en.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103733}, 'id': 1275010934, 'type': 'edit', 'namespace': 0, 'title': 'Divyaa Unni', 'comment': '/* Filmography */', 'timestamp': 1592991287, 'user': '60.243.70.0', 'bot': False, 'minor': False, 'length': {'old': 10594, 'new': 10596}, 'revision': {'old': 960072005, 'new': 964234135}, 'server_url': 'https://en.wikipedia.org', 'server_name': 'en.wikipedia.org', 'server_script_path': '/w', 'wiki': 'enwiki', 'parsedcomment': '<span dir="auto"><span class="autocomment"><a href="/wiki/Divyaa_Unni#Filmography" title="Divyaa Unni">→\u200eFilmography</a></span></span>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=951, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=28, timestamp=1592991288578, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://fr.wikisource.org/wiki/Page:Hugo_-_Actes_et_paroles_-_volume_2.djvu/228', 'request_id': '7a47f10e-aec3-460a-8795-8bc65743fba1', 'id': '1194cca3-e56d-4583-8bbb-d823e99aa4ea', 'dt': '2020-06-24T09:34:48Z', 'domain': 'fr.wikisource.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103734}, 'id': 14756803, 'type': 'edit', 'namespace': 104, 'title': 'Page:Hugo - Actes et paroles - volume 2.djvu/228', 'comment': '', 'timestamp': 1592991288, 'user': 'Jps726', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 2976, 'new': 2979}, 'revision': {'old': 10528320, 'new': 10528325}, 'server_url': 'https://fr.wikisource.org', 'server_name': 'fr.wikisource.org', 'server_script_path': '/w', 'wiki': 'frwikisource', 'parsedcomment': ''}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=876, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=29, timestamp=1592991288583, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q96620506', 'request_id': '3774b542-848e-4c13-a2a5-c8dfa7c1f609', 'id': '32cb902a-f1fa-4604-b719-6d1e13315719', 'dt': '2020-06-24T09:34:47Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103735}, 'id': 1254672711, 'type': 'edit', 'namespace': 0, 'title': 'Q96620506', 'comment': '/* wbsetqualifier-add:1| */ [[Property:P1476]]: 採收果凍森林 雙連埤 蓴(ㄔㄨㄣˊ)菜季, [[:toollabs:quickstatements/#/batch/37634|batch #37634]]', 'timestamp': 1592991287, 'user': 'M80126colin', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 2370, 'new': 2752}, 'revision': {'old': 1215381594, 'new': 1215411717}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">已加入量詞：</span></span> <a href="/wiki/Property:P1476" title="Property:P1476">Property:P1476</a>: 採收果凍森林 雙連埤 蓴(ㄔㄨㄣˊ)菜季, <a href="https://tools.wmflabs.org/quickstatements/#.2Fbatch.2F37634" class="extiw" title="toollabs:quickstatements/">batch #37634</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1433, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=30, timestamp=1592991288584, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://ru.wikinews.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86', 'request_id': 'd86dc902-3fbe-4884-8ce2-673fdd075829', 'id': '327c3ed5-f974-4f5c-a692-8fd351079e80', 'dt': '2020-06-24T09:34:47Z', 'domain': 'ru.wikinews.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103736}, 'id': 13308591, 'type': 'categorize', 'namespace': 14, 'title': 'Категория:Статистика страниц', 'comment': '[[:Викиновости:Статистика страниц/Категория:Бартонь]] добавлена в категорию', 'timestamp': 1592991287, 'user': 'NewsBots', 'bot': True, 'server_url': 'https://ru.wikinews.org', 'server_name': 'ru.wikinews.org', 'server_script_path': '/w', 'wiki': 'ruwikinews', 'parsedcomment': '<a href="/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8:%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%91%D0%B0%D1%80%D1%82%D0%BE%D0%BD%D1%8C" title="Викиновости:Статистика страниц/Категория:Бартонь">Викиновости:Статистика страниц/Категория:Бартонь</a> добавлена в категорию'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2316, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=31, timestamp=1592991288665, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://ru.wikinews.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A1%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86%D1%8B_%D1%81_%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B0%D0%BC%D0%B8', 'request_id': 'd86dc902-3fbe-4884-8ce2-673fdd075829', 'id': '4b03be92-2e12-4dea-b8ee-96810fc4df5f', 'dt': '2020-06-24T09:34:47Z', 'domain': 'ru.wikinews.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103737}, 'id': 13308592, 'type': 'categorize', 'namespace': 14, 'title': 'Категория:Страницы с графиками', 'comment': '[[:Викиновости:Статистика страниц/Категория:Бартонь]] добавлена в категорию', 'timestamp': 1592991287, 'user': 'NewsBots', 'bot': True, 'server_url': 'https://ru.wikinews.org', 'server_name': 'ru.wikinews.org', 'server_script_path': '/w', 'wiki': 'ruwikinews', 'parsedcomment': '<a href="/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8:%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%91%D0%B0%D1%80%D1%82%D0%BE%D0%BD%D1%8C" title="Викиновости:Статистика страниц/Категория:Бартонь">Викиновости:Статистика страниц/Категория:Бартонь</a> добавлена в категорию'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2330, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=32, timestamp=1592991288666, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q57245619', 'request_id': '4cac3039-4394-4581-991f-11723ed2efae', 'id': '8d6dad81-a76b-437d-96c9-3a209e87a0c2', 'dt': '2020-06-24T09:34:47Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103738}, 'id': 1254672712, 'type': 'edit', 'namespace': 0, 'title': 'Q57245619', 'comment': '/* wbcreateclaim-create:1| */ [[Property:P921]]: [[Q93165]], [[:toollabs:quickstatements/#/batch/37626|batch #37626]]', 'timestamp': 1592991287, 'user': 'Research Bot', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 10362, 'new': 10790}, 'revision': {'old': 1164062782, 'new': 1215411716}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Created claim: </span></span> <a href="/wiki/Property:P921" title="Property:P921">Property:P921</a>: <a href="/wiki/Q93165" title="Q93165">Q93165</a>, <a href="https://tools.wmflabs.org/quickstatements/#.2Fbatch.2F37626" class="extiw" title="toollabs:quickstatements/">batch #37626</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1275, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=33, timestamp=1592991288666, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://vi.wikipedia.org/wiki/Th%E1%BA%A3o_lu%E1%BA%ADn_Th%C3%A0nh_vi%C3%AAn:116.102.92.53', 'request_id': '4a880ef7-0cf3-4af7-a00f-0cba22d91211', 'id': '9da65b51-86f1-4f1c-b7e9-aee3f9a8aba5', 'dt': '2020-06-24T09:34:48Z', 'domain': 'vi.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512103739}, 'id': 98539451, 'type': 'edit', 'namespace': 3, 'title': 'Thảo luận Thành viên:116.102.92.53', 'comment': 'tltv using [[Project:AWB|AWB]]', 'timestamp': 1592991288, 'user': 'TuanminhBot', 'bot': True, 'minor': True, 'patrolled': True, 'length': {'old': 4589, 'new': 5440}, 'revision': {'old': 45464432, 'new': 62636568}, 'server_url': 'https://vi.wikipedia.org', 'server_name': 'vi.wikipedia.org', 'server_script_path': '/w', 'wiki': 'viwiki', 'parsedcomment': 'tltv using <a href="/wiki/Wikipedia:AWB" class="mw-redirect" title="Wikipedia:AWB">AWB</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1011, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ...
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1509, timestamp=1592991334790, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q38076759', 'request_id': '1933ea60-fb7b-4c1d-ac21-60a6605ee269', 'id': 'a7ec5104-c8fa-412b-97ac-229368bef7bc', 'dt': '2020-06-24T09:35:34Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105215}, 'id': 1254673299, 'type': 'edit', 'namespace': 0, 'title': 'Q38076759', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592991334, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 79181, 'new': 80043}, 'revision': {'old': 1209535958, 'new': 1215412298}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1510, timestamp=1592991334796, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q16090801', 'request_id': 'b53616c9-79b0-425c-803b-32b69d51be4a', 'id': 'b24e228d-50fc-480f-a73b-5f753a99e9a4', 'dt': '2020-06-24T09:35:34Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105216}, 'id': 1254673300, 'type': 'edit', 'namespace': 0, 'title': 'Q16090801', 'comment': '/* wbsetdescription-add:1|ko */ 산림환경학과 교수를 지낸 대한민국의 산림학자', 'timestamp': 1592991334, 'user': 'Christian140', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 5380, 'new': 5503}, 'revision': {'old': 1215412284, 'new': 1215412297}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Beschreibung für [ko] hinzugefügt: </span></span> 산림환경학과 교수를 지낸 대한민국의 산림학자'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1197, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1511, timestamp=1592991334830, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://arz.wikipedia.org/wiki/%D8%AA%D8%B5%D9%86%D9%8A%D9%81:%D8%B5%D9%81%D8%AD%D8%A7%D8%AA_%D8%AA%D8%B3%D8%AA%D8%AE%D8%AF%D9%85_%D8%AE%D8%A7%D8%B5%D9%8A%D8%A9_P3083', 'request_id': '289384e5-32c9-4f93-bc30-1242a30f86c8', 'id': '8900634c-38fe-473e-a49e-612b2955ad13', 'dt': '2020-06-24T09:35:30Z', 'domain': 'arz.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105217}, 'id': 11577151, 'type': 'categorize', 'namespace': 14, 'title': 'تصنيف:صفحات تستخدم خاصية P3083', 'comment': 'أضيفت [[:ZFOURGE UDS 4966 (مجره)]] إلى التصنيف، [[Special:WhatLinksHere/ZFOURGE UDS 4966 (مجره)|هذه الصفحة مضمنة في صفحات اخرى]]', 'timestamp': 1592991330, 'user': 'HitomiAkane', 'bot': False, 'server_url': 'https://arz.wikipedia.org', 'server_name': 'arz.wikipedia.org', 'server_script_path': '/w', 'wiki': 'arzwiki', 'parsedcomment': 'أضيفت <a href="/wiki/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="ZFOURGE UDS 4966 (مجره)">ZFOURGE UDS 4966 (مجره)</a> إلى التصنيف، <a href="/wiki/%D8%AE%D8%A7%D8%B5:%D8%A7%D9%8A%D9%87_%D8%A8%D9%8A%D9%88%D8%B5%D9%84_%D9%87%D9%86%D8%A7/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="خاص:ايه بيوصل هنا/ZFOURGE UDS 4966 (مجره)">هذه الصفحة مضمنة في صفحات اخرى</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2021, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1512, timestamp=1592991334838, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://arz.wikipedia.org/wiki/%D8%AA%D8%B5%D9%86%D9%8A%D9%81:%D8%B5%D9%81%D8%AD%D8%A7%D8%AA_%D8%A8%D9%87%D8%A7_%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA_%D9%88%D9%8A%D9%83%D9%8A_%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA', 'request_id': '289384e5-32c9-4f93-bc30-1242a30f86c8', 'id': '34969790-b203-428a-a6de-71559ed6f33d', 'dt': '2020-06-24T09:35:30Z', 'domain': 'arz.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105218}, 'id': 11577152, 'type': 'categorize', 'namespace': 14, 'title': 'تصنيف:صفحات بها بيانات ويكي بيانات', 'comment': 'أضيفت [[:ZFOURGE UDS 4966 (مجره)]] إلى التصنيف، [[Special:WhatLinksHere/ZFOURGE UDS 4966 (مجره)|هذه الصفحة مضمنة في صفحات اخرى]]', 'timestamp': 1592991330, 'user': 'HitomiAkane', 'bot': False, 'server_url': 'https://arz.wikipedia.org', 'server_name': 'arz.wikipedia.org', 'server_script_path': '/w', 'wiki': 'arzwiki', 'parsedcomment': 'أضيفت <a href="/wiki/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="ZFOURGE UDS 4966 (مجره)">ZFOURGE UDS 4966 (مجره)</a> إلى التصنيف، <a href="/wiki/%D8%AE%D8%A7%D8%B5:%D8%A7%D9%8A%D9%87_%D8%A8%D9%8A%D9%88%D8%B5%D9%84_%D9%87%D9%86%D8%A7/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="خاص:ايه بيوصل هنا/ZFOURGE UDS 4966 (مجره)">هذه الصفحة مضمنة في صفحات اخرى</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2109, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1513, timestamp=1592991334847, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q61918536', 'request_id': '8a4b0c2b-a363-4a72-ac16-4cd99a479e27', 'id': 'd3524a31-1035-467b-a1dc-28680798fe14', 'dt': '2020-06-24T09:35:34Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105219}, 'id': 1254673301, 'type': 'edit', 'namespace': 0, 'title': 'Q61918536', 'comment': '/* wbcreateclaim-create:1| */ [[Property:P8363]]: [[Q78089383]], [[:toollabs:quickstatements/#/batch/37579|batch #37579]]', 'timestamp': 1592991334, 'user': 'Tibbs001', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 10289, 'new': 10725}, 'revision': {'old': 1168446241, 'new': 1215412301}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Created claim: </span></span> <a href="/wiki/Property:P8363" title="Property:P8363">Property:P8363</a>: <a href="/wiki/Q78089383" title="Q78089383">Q78089383</a>, <a href="https://tools.wmflabs.org/quickstatements/#.2Fbatch.2F37579" class="extiw" title="toollabs:quickstatements/">batch #37579</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1287, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1514, timestamp=1592991334854, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://arz.wikipedia.org/wiki/%D8%AA%D8%B5%D9%86%D9%8A%D9%81:%D9%85%D9%82%D8%A7%D9%84%D8%A7%D8%AA_%D8%AA%D8%AD%D8%AA%D9%88%D9%8A_%D9%86%D8%B5%D8%A7_%D8%A8%D8%A7%D9%84%D8%A5%D9%86%D8%AC%D9%84%D9%8A%D8%B2%D9%89', 'request_id': '289384e5-32c9-4f93-bc30-1242a30f86c8', 'id': '5569ca0a-6dbe-498b-8525-fe899e0dcb2a', 'dt': '2020-06-24T09:35:30Z', 'domain': 'arz.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105220}, 'id': 11577153, 'type': 'categorize', 'namespace': 14, 'title': 'تصنيف:مقالات تحتوي نصا بالإنجليزى', 'comment': 'أضيفت [[:ZFOURGE UDS 4966 (مجره)]] إلى التصنيف، [[Special:WhatLinksHere/ZFOURGE UDS 4966 (مجره)|هذه الصفحة مضمنة في صفحات اخرى]]', 'timestamp': 1592991330, 'user': 'HitomiAkane', 'bot': False, 'server_url': 'https://arz.wikipedia.org', 'server_name': 'arz.wikipedia.org', 'server_script_path': '/w', 'wiki': 'arzwiki', 'parsedcomment': 'أضيفت <a href="/wiki/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="ZFOURGE UDS 4966 (مجره)">ZFOURGE UDS 4966 (مجره)</a> إلى التصنيف، <a href="/wiki/%D8%AE%D8%A7%D8%B5:%D8%A7%D9%8A%D9%87_%D8%A8%D9%8A%D9%88%D8%B5%D9%84_%D9%87%D9%86%D8%A7/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="خاص:ايه بيوصل هنا/ZFOURGE UDS 4966 (مجره)">هذه الصفحة مضمنة في صفحات اخرى</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2107, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1515, timestamp=1592991334863, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q15355013', 'request_id': 'dcbb5d38-5dc4-4053-a010-be5375a4cf8a', 'id': '30419b8e-4081-4e6d-a577-b00eb4abc248', 'dt': '2020-06-24T09:35:34Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105221}, 'id': 1254673302, 'type': 'edit', 'namespace': 0, 'title': 'Q15355013', 'comment': '/* wbsetreference-set:2| */ [[Property:P141]]: [[Q3245245]]', 'timestamp': 1592991334, 'user': 'SuccuBot', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 19246, 'new': 19246}, 'revision': {'old': 1197410872, 'new': 1215412304}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Fundstelle der Aussage geändert: </span></span> <a href="/wiki/Property:P141" title="Property:P141">Property:P141</a>: <a href="/wiki/Q3245245" title="Q3245245">Q3245245</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1099, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1516, timestamp=1592991334866, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://arz.wikipedia.org/wiki/%D8%AA%D8%B5%D9%86%D9%8A%D9%81:%D8%B5%D9%81%D8%AD%D8%A7%D8%AA_%D9%88%D9%8A%D9%83%D9%8A_%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA_%D8%A8%D8%AD%D8%A7%D8%AC%D8%A9_%D9%84%D8%AA%D8%B3%D9%85%D9%8A%D8%A9_%D8%B9%D8%B1%D8%A8%D9%8A%D8%A9', 'request_id': '289384e5-32c9-4f93-bc30-1242a30f86c8', 'id': 'bf217552-57b2-4777-b82f-55b19717879a', 'dt': '2020-06-24T09:35:30Z', 'domain': 'arz.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512105222}, 'id': 11577154, 'type': 'categorize', 'namespace': 14, 'title': 'تصنيف:صفحات ويكي بيانات بحاجة لتسمية عربية', 'comment': 'أضيفت [[:ZFOURGE UDS 4966 (مجره)]] إلى التصنيف، [[Special:WhatLinksHere/ZFOURGE UDS 4966 (مجره)|هذه الصفحة مضمنة في صفحات اخرى]]', 'timestamp': 1592991330, 'user': 'HitomiAkane', 'bot': False, 'server_url': 'https://arz.wikipedia.org', 'server_name': 'arz.wikipedia.org', 'server_script_path': '/w', 'wiki': 'arzwiki', 'parsedcomment': 'أضيفت <a href="/wiki/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="ZFOURGE UDS 4966 (مجره)">ZFOURGE UDS 4966 (مجره)</a> إلى التصنيف، <a href="/wiki/%D8%AE%D8%A7%D8%B5:%D8%A7%D9%8A%D9%87_%D8%A8%D9%8A%D9%88%D8%B5%D9%84_%D9%87%D9%86%D8%A7/ZFOURGE_UDS_4966_(%D9%85%D8%AC%D8%B1%D9%87)" title="خاص:ايه بيوصل هنا/ZFOURGE UDS 4966 (مجره)">هذه الصفحة مضمنة في صفحات اخرى</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2195, serialized_header_size=-1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a3a5fa052a98> in <module>
#      11 consumer.subscribe(['wiki-changes']) #kafka topic
#      12
# ---> 13 for message in consumer:
#      14     print("**************************************")
#      15     print("**************************************")
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in __next__(self)
#    1190             return self.next_v1()
#    1191         else:
# -> 1192             return self.next_v2()
#    1193
#    1194     def next_v2(self):
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in next_v2(self)
#    1198                 self._iterator = self._message_generator_v2()
#    1199             try:
# -> 1200                 return next(self._iterator)
#    1201             except StopIteration:
#    1202                 self._iterator = None
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1113     def _message_generator_v2(self):
#    1114         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1115         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1116         for tp, records in six.iteritems(record_map):
#    1117             # Generators are stateful, and it is possible that the tp / records
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     652         remaining = timeout_ms
#     653         while True:
# --> 654             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     655             if records:
#     656                 return records
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     699
#     700         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 701         self._client.poll(timeout_ms=timeout_ms)
#     702         # after the long poll, we should check whether the group needs to rebalance
#     703         # prior to returning data so that the group can stabilize faster
#
# /opt/conda/lib/python3.7/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     598                     timeout = max(0, timeout)  # avoid negative timeouts
#     599
# --> 600                 self._poll(timeout / 1000)
#     601
#     602             # called without the lock to avoid deadlock potential
#
# /opt/conda/lib/python3.7/site-packages/kafka/client_async.py in _poll(self, timeout)
#     630
#     631         start_select = time.time()
# --> 632         ready = self._selector.select(timeout)
#     633         end_select = time.time()
#     634         if self._sensors:
#
# /opt/conda/lib/python3.7/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:
