# %% [markdown]
# # Install Libraries (if needed)

# %%
#!pip install sseclient

# %%
#!pip install kafka-python

# %%
# References: https://wikitech.wikimedia.org/wiki/Event_Platform/EventStreams
import json
from sseclient import SSEClient as EventSource
from kafka import KafkaConsumer

# Create consumer
consumer = KafkaConsumer(bootstrap_servers='kafka-server:9092', #Kafka server
                        auto_offset_reset='earliest', #Consume messages from the beggining
                        value_deserializer=lambda m: json.loads(m.decode('utf-8'))) #json deserializer

consumer.subscribe(['wiki-changes']) #kafka topic

for message in consumer:
    print("**************************************")
    print("**************************************")
    print("**************************************")
    print(message)
# Out:
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=0, timestamp=1592992669966, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q37332825', 'request_id': 'c81c6261-13ab-4bc0-8eb4-0a5f2e887ba1', 'id': 'cdacf9a7-509d-4f6e-a556-abf3aa930fbe', 'dt': '2020-06-24T09:57:49Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144613}, 'id': 1254686444, 'type': 'edit', 'namespace': 0, 'title': 'Q37332825', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992669, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 17011, 'new': 17873}, 'revision': {'old': 845039110, 'new': 1215425178}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1093, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=1, timestamp=1592992669972, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wikipedia.org/wiki/Juliusz_Pawel_Schauder', 'request_id': 'f947d05b-7bdf-4ce2-9fdb-679925761106', 'id': 'acc7336b-e048-4e0e-83ef-f2c7feb56ca9', 'dt': '2020-06-24T09:57:49Z', 'domain': 'en.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144614}, 'id': 1275016001, 'type': 'new', 'namespace': 0, 'title': 'Juliusz Pawel Schauder', 'comment': '[[WP:AES|←]]Redirected page to [[Juliusz Schauder]]', 'timestamp': 1592992669, 'user': 'Shyamal', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'new': 30}, 'revision': {'new': 964236828}, 'server_url': 'https://en.wikipedia.org', 'server_name': 'en.wikipedia.org', 'server_script_path': '/w', 'wiki': 'enwiki', 'parsedcomment': '<a href="/wiki/Wikipedia:AES" class="mw-redirect" title="Wikipedia:AES">←</a>Redirected page to <a href="/wiki/Juliusz_Schauder" title="Juliusz Schauder">Juliusz Schauder</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1028, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=2, timestamp=1592992669993, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q34371411', 'request_id': '833d86e9-f36d-4f80-ba73-d9cccf979373', 'id': 'ad1b3561-c578-43b5-9c34-99afc91ca6f5', 'dt': '2020-06-24T09:57:49Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144615}, 'id': 1254686445, 'type': 'edit', 'namespace': 0, 'title': 'Q34371411', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992669, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 21449, 'new': 22311}, 'revision': {'old': 1017720126, 'new': 1215425176}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=3, timestamp=1592992670049, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q80097854', 'request_id': '32970d21-0033-42e2-95b0-4ebea56ce805', 'id': '35d4f3b3-5f61-4097-a48b-ee951aa43b9f', 'dt': '2020-06-24T09:57:49Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144616}, 'id': 1254686446, 'type': 'edit', 'namespace': 0, 'title': 'Q80097854', 'comment': '/* wbeditentity-update-languages-short:0||nl */ nl-description, [[User:Edoderoobot/Set-nl-description|python code]] - IR-far', 'timestamp': 1592992669, 'user': 'Edoderoobot', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 6489, 'new': 6576}, 'revision': {'old': 1085230667, 'new': 1215425182}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Changed label, description and/or aliases in nl: </span></span> nl-description, <a href="/wiki/User:Edoderoobot/Set-nl-description" title="User:Edoderoobot/Set-nl-description">python code</a> - IR-far'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1183, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=4, timestamp=1592992670050, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q34560646', 'request_id': 'afd11124-bfe6-46cf-a92f-7f44f67892e1', 'id': '5a8b918f-cc27-4f79-a479-51419b7166fe', 'dt': '2020-06-24T09:57:49Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144617}, 'id': 1254686447, 'type': 'edit', 'namespace': 0, 'title': 'Q34560646', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992669, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 27423, 'new': 28285}, 'revision': {'old': 1020142521, 'new': 1215425177}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=5, timestamp=1592992670084, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D1%81%D1%81%D0%BC%D0%B5%D1%80%D1%82%D0%BD%D1%8B%D0%B9_%D0%BF%D0%BE%D0%BB%D0%BA', 'request_id': 'f0aa968c-3b18-43c2-b6df-2f35f7196faa', 'id': 'bef27f6e-6fff-4614-b461-6a8c66f5f69f', 'dt': '2020-06-24T09:57:46Z', 'domain': 'ru.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144618}, 'id': 393385775, 'type': 'edit', 'namespace': 0, 'title': 'Бессмертный полк', 'comment': '', 'timestamp': 1592992666, 'user': '80.89.79.109', 'bot': False, 'minor': False, 'length': {'old': 84732, 'new': 84704}, 'revision': {'old': 107378056, 'new': 107831294}, 'server_url': 'https://ru.wikipedia.org', 'server_name': 'ru.wikipedia.org', 'server_script_path': '/w', 'wiki': 'ruwiki', 'parsedcomment': ''}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=942, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=6, timestamp=1592992670084, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://ru.wikinews.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86', 'request_id': '851ff47b-972e-4eac-b8d7-cb6a186e9170', 'id': 'b4f58a96-8e51-4784-80da-4eee9652188c', 'dt': '2020-06-24T09:57:49Z', 'domain': 'ru.wikinews.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144619}, 'id': 13310505, 'type': 'categorize', 'namespace': 14, 'title': 'Категория:Статистика страниц', 'comment': '[[:Викиновости:Статистика страниц/Барухина]] добавлена в категорию', 'timestamp': 1592992669, 'user': 'NewsBots', 'bot': True, 'server_url': 'https://ru.wikinews.org', 'server_name': 'ru.wikinews.org', 'server_script_path': '/w', 'wiki': 'ruwikinews', 'parsedcomment': '<a href="/wiki/%D0%92%D0%B8%D0%BA%D0%B8%D0%BD%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8:%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86/%D0%91%D0%B0%D1%80%D1%83%D1%85%D0%B8%D0%BD%D0%B0" title="Викиновости:Статистика страниц/Барухина">Викиновости:Статистика страниц/Барухина</a> добавлена в категорию'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=2120, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=7, timestamp=1592992670085, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://ru.wikinews.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A1%D1%82%D1%80%D0%B0%D0%BD%D0%B8%D1%86%
}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1243, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=18, timestamp=1592992670460, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://it.wikipedia.org/wiki/Universit%C3%A0_pi%C3%B9_antiche_in_attivit%C3%A0', 'request_id': '9097c778-e89f-4baa-a91c-10f4cd154b12', 'id': '0d3ec434-3d05-4de6-bcf8-d188642566b7', 'dt': '2020-06-24T09:57:50Z', 'domain': 'it.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144631}, 'type': 'log', 'namespace': 0, 'title': 'Università più antiche in attività', 'comment': '', 'timestamp': 1592992670, 'user': 'Skyfall', 'bot': False, 'log_id': 52311268, 'log_type': 'patrol', 'log_action': 'patrol', 'log_params': {'curid': '113883806', 'previd': '112121254', 'auto': 0}, 'log_action_comment': 'marked revision 113883806 of [[Università più antiche in attività]] patrolled ', 'server_url': 'https://it.wikipedia.org', 'server_name': 'it.wikipedia.org', 'server_script_path': '/w', 'wiki': 'itwiki', 'parsedcomment': ''}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=986, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=19, timestamp=1592992670498, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q21218711', 'request_id': 'aa81804b-ff6d-4fe9-84da-984372065172', 'id': '964cfcfb-f800-4438-84b4-3af9620c75d6', 'dt': '2020-06-24T09:57:49Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144632}, 'id': 1254686456, 'type': 'edit', 'namespace': 0, 'title': 'Q21218711', 'comment': '/* wbsetlabel-add:1|vi */ Sinoxylonini', 'timestamp': 1592992669, 'user': 'SuccuBot', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 4606, 'new': 4677}, 'revision': {'old': 1215425168, 'new': 1215425190}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Bezeichnung für [vi] hinzugefügt: </span></span> Sinoxylonini'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=961, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=20, timestamp=1592992670623, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://vi.wikipedia.org/wiki/Th%E1%BA%A3o_lu%E1%BA%ADn_Th%C3%A0nh_vi%C3%AAn:116.102.101.29', 'request_id': '29a0c1c0-7a2f-46fd-a256-02ae7179ac8d', 'id': '366ec78a-3e0d-4a5e-a6bf-b6cc13ec1e66', 'dt': '2020-06-24T09:57:50Z', 'domain': 'vi.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144633}, 'id': 98540103, 'type': 'edit', 'namespace': 3, 'title': 'Thảo luận Thành viên:116.102.101.29', 'comment': 'tltv using [[Project:AWB|AWB]]', 'timestamp': 1592992670, 'user': 'TuanminhBot', 'bot': True, 'minor': True, 'patrolled': True, 'length': {'old': 4589, 'new': 5440}, 'revision': {'old': 45465066, 'new': 62637122}, 'server_url': 'https://vi.wikipedia.org', 'server_name': 'vi.wikipedia.org', 'server_script_path': '/w', 'wiki': 'viwiki', 'parsedcomment': 'tltv using <a href="/wiki/Wikipedia:AWB" class="mw-redirect" title="Wikipedia:AWB">AWB</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1013, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=21, timestamp=1592992670634, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://commons.wikimedia.org/wiki/File:Fermanville,_fort_du_cap_L%C3%A9vi.jpg', 'request_id': '7c7791e3-debb-4e42-8234-9ba6c371452e', 'id': 'e636f8ba-032a-4767-8b90-fef62f70bfd7', 'dt': '2020-06-24T09:57:49Z', 'domain': 'commons.wikimedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144634}, 'id': 1406895686, 'type': 'edit', 'namespace': 6, 'title': 'File:Fermanville, fort du cap Lévi.jpg', 'comment': '/* wbsetclaim-create:2||1 */ [[d:Special:EntityPage/P180]]: [[d:Special:EntityPage/Q2937064]]', 'timestamp': 1592992669, 'user': "Martin'", 'bot': False, 'minor': False, 'patrolled': False, 'length': {'old': 2988, 'new': 3403}, 'revision': {'old': 428598241, 'new': 428598243}, 'server_url': 'https://commons.wikimedia.org', 'server_name': 'commons.wikimedia.org', 'server_script_path': '/w', 'wiki': 'commonswiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">
, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=26, timestamp=1592992670770, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q40667285', 'request_id': '248cfac6-7003-459c-a5f0-5685f5f203af', 'id': 'a6f3c306-ee80-4117-bba6-84655a74598f', 'dt': '2020-06-24T09:57:50Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144639}, 'id': 1254686461, 'type': 'edit', 'namespace': 0, 'title': 'Q40667285', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992670, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 21838, 'new': 22700}, 'revision': {'old': 814482554, 'new': 1215425194}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1093, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=27, timestamp=1592992670790, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q3134848', 'request_id': '5120d125-222a-47fd-aacb-e1a3d51160e2', 'id': '3350cd29-7659-4ca1-851b-fc2c3969eaab', 'dt': '2020-06-24T09:57:50Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144640}, 'id': 1254686463, 'type': 'edit', 'namespace': 0, 'title': 'Q3134848', 'comment': '/* wbsetlabel-add:1|vi */ Heteromyinae', 'timestamp': 1592992670, 'user': 'SuccuBot', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 19445, 'new': 19516}, 'revision': {'old': 1181558948, 'new': 1215425193}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Bezeichnung für [vi] hinzugefügt: </span></span> Heteromyinae'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=961, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=28, timestamp=1592992670801, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q63958632', 'request_id': '932bbfe1-91d2-466c-9882-66f1f716af3c', 'id': '0320e8bf-e96d-463e-8a2e-183bc794b224', 'dt': '2020-06-24T09:57:50Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144641}, 'id': 1254686462, 'type': 'edit', 'namespace': 0, 'title': 'Q63958632', 'comment': '/* wbsetreference-add:2| */ [[Property:P921]]: [[Q93165]], [[:toollabs:quickstatements/#/batch/37626|batch #37626]]', 'timestamp': 1592992670, 'user': 'Research Bot', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 9552, 'new': 10002}, 'revision': {'old': 1215425183, 'new': 1215425199}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Added reference to claim: </span></span> <a href="/wiki/Property:P921" title="Property:P921">Property:P921</a>: <a href="/wiki/Q93165" title="Q93165">Q93165</a>, <a href="https://tools.wmflabs.org/quickstatements/#.2Fbatch.2F37626" class="extiw" title="toollabs:quickstatements/">batch #37626</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1283, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=29, timestamp=1592992670842, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q34371417', 'request_id': '2422315b-667f-433f-b38c-47eb9c17ac68', 'id': 'd8505390-8f86-4bd0-9a06-5371d4dea7f9', 'dt': '2020-06-24T09:57:50Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144642}, 'id': 1254686465, 'type': 'edit', 'namespace': 0, 'title': 'Q34371417', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992670, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 21763, 'new': 22625}, 'revision': {'old': 1186666485, 'new': 1215425198}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=30, timestamp=1592992670870, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q36577950', 'request_id': '8167f43d-3341-4c0a-b3bc-2effed20c0c0', 'id': 'c6d9f47c-f302-4590-99d7-50df0300294d', 'dt': '2020-06-24T09:57:50Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144643}, 'id': 1254686466, 'type': 'edit', 'namespace': 0, 'title': 'Q36577950', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992670, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 30814, 'new': 31676}, 'revision': {'old': 1104235841, 'new': 1215425197}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=31, timestamp=1592992670912, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q83812826', 'request_id': '03fa04aa-bd36-427a-a6bb-d6e8feb6ec3f', 'id': 'fa141418-b2a3-4b6f-87d5-5d2b97c7800c', 'dt': '2020-06-24T09:57:50Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144644}, 'id': 1254686467, 'type': 'edit', 'namespace': 0, 'title': 'Q83812826', 'comment': '/* wbsetlabel-add:1|vi */ Senecio robustus', 'timestamp': 1592992670, 'user': 'SuccuBot', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 10425, 'new': 10500}, 'revision': {'old': 1215425184, 'new': 1215425202}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Bezeichnung für [vi] hinzugefügt: </span></span> Senecio robustus'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=971, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=32, timestamp=1592992670949, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wikipedia.org/wiki/Buick_Encore', 'request_id': '98684196-7d4c-4a5a-a473-a46bf9ce29da', 'id': 'f70cbd8a-9c67-4a27-b6b6-f1af3751172c', 'dt': '2020-06-24T09:57:49Z', 'domain': 'en.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512144645}, 'id': 1275016003, 'type': 'edit', 'namespace': 0, 'title': 'Buick Encore', 'comment': '/* Second generation (2020–present) */', 'timestamp': 1592992669, 'user': 'Andra Febrian', 'bot': False, 'minor': False, 'length': {'old': 16224, 'new': 15994}, 'revision': {'old': 961179603, 'new': 964236829}, 'server_url': 'https://en.wikipedia.org', 'server_name': 'en.wikipedia.org', 'server_script_path': '/w', 'wiki': 'enwiki', 'parsedcomment': '<span dir="auto"><span class="autocomment"><a href="/wiki/Buick_Encore#Second_generation_(2020–present)" title="Buick Encore">→\u200eSecond generation (2020–present)</a></span></span>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1035, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ...
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=934, timestamp=1592992692864, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q92478930', 'request_id': '27b41f30-5aad-4f14-8f2d-ac985e3f66a8', 'id': '6a4ba001-47e8-458d-b7d9-56f6fb969493', 'dt': '2020-06-24T09:58:12Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512145547}, 'id': 1254686996, 'type': 'edit', 'namespace': 0, 'title': 'Q92478930', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992692, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 27764, 'new': 28626}, 'revision': {'old': 1193834561, 'new': 1215425716}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=935, timestamp=1592992692867, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wiktionary.org/wiki/Category:Mandarin_lemmas', 'request_id': 'baaf637c-361c-4801-a139-b789beccd5f7', 'id': 'fe6b4610-ce2a-4ce6-8eb2-17e29262a2b4', 'dt': '2020-06-24T09:58:11Z', 'domain': 'en.wiktionary.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2
z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512145551}, 'id': 1254686997, 'type': 'edit', 'namespace': 0, 'title': 'Q83813628', 'comment': '/* wbsetlabel-add:1|vi */ Eugenia hatschbachii', 'timestamp': 1592992692, 'user': 'SuccuBot', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 7987, 'new': 8066}, 'revision': {'old': 1215425704, 'new': 1215425723}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Bezeichnung für [vi] hinzugefügt: </span></span> Eugenia hatschbachii'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=977, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=939, timestamp=1592992692890, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q73505663', 'request_id': '4d8a5c18-ddfe-42c5-8c2e-cbc655480859', 'id': '5c96607e-c133-4e4f-aa44-6c6f0b53b690', 'dt': '2020-06-24T09:58:12Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512145552}, 'id': 1254686994, 'type': 'edit', 'namespace': 0, 'title': 'Q73505663', 'comment': '/* wbsetreference-add:2| */ [[Property:P921]]: [[Q93165]], [[:toollabs:quickstatements/#/batch/37626|batch #37626]]', 'timestamp': 1592992692, 'user': 'Research Bot', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'old': 35608, 'new': 36058}, 'revision': {'old': 1215425702, 'new': 1215425722}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Added reference to claim: </span></span> <a href="/wiki/Property:P921" title="Property:P921">Property:P921</a>: <a href="/wiki/Q93165" title="Q93165">Q93165</a>, <a href="https://tools.wmflabs.org/quickstatements/#.2Fbatch.2F37626" class="extiw" title="toollabs:quickstatements/">batch #37626</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1284, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=940, timestamp=1592992692894, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://en.wiktionary.org/wiki/Category:Chinese_nouns', 'request_id': 'baaf637c-361c-4801-a139-b789beccd5f7', 'id': 'fd00bbdd-7cbf-4cc9-99d8-586a5ff39e09', 'dt': '2020-06-24T09:58:11Z', 'domain': 'en.wiktionary.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512145553}, 'id': 76724036, 'type': 'categorize', 'namespace': 14, 'title': 'Category:Chinese nouns', 'comment': '[[:连通器]] added to category', 'timestamp': 1592992691, 'user': '沈澄心', 'bot': False, 'server_url': 'https://en.wiktionary.org', 'server_name': 'en.wiktionary.org', 'server_script_path': '/w', 'wiki': 'enwiktionary', 'parsedcomment': '<a href="/wiki/%E8%BF%9E%E9%80%9A%E5%99%A8" title="连通器">连通器</a> added to category'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=876, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=941, timestamp=1592992692898, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://www.wikidata.org/wiki/Q72041051', 'request_id': 'c974097f-65f8-4596-b336-084b724c4a41', 'id': 'a46117f5-5fd9-4c9e-8c17-e5647c890410', 'dt': '2020-06-24T09:58:12Z', 'domain': 'www.wikidata.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512145554}, 'id': 1254686998, 'type': 'edit', 'namespace': 0, 'title': 'Q72041051', 'comment': '/* wbsetclaim-create:2||1 */ [[Property:P31]]: [[Q7318358]]', 'timestamp': 1592992692, 'user': 'GZWDer (flood)', 'bot': True, 'minor': False, 'patrolled': True, 'length': {'old': 27396, 'new': 28258}, 'revision': {'old': 1138152896, 'new': 1215425720}, 'server_url': 'https://www.wikidata.org', 'server_name': 'www.wikidata.org', 'server_script_path': '/w', 'wiki': 'wikidatawiki', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">创建声称：</span></span> <a href="/wiki/Property:P31" title="Property:P31">Property:P31</a>: <a href="/wiki/Q7318358" title="Q7318358">Q7318358</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=1094, serialized_header_size=-1)
# **************************************
# **************************************
# **************************************
# ConsumerRecord(topic='wiki-changes', partition=0, offset=942, timestamp=1592992692919, timestamp_type=0, key=None, value={'$schema': '/mediawiki/recentchange/1.0.0', 'meta': {'uri': 'https://zh.wikipedia.org/wiki/User_talk:MasterGaysha', 'request_id': '31dd3f1c-15e7-4285-a7e9-cf350c537356', 'id': '2e63482d-b7e8-448c-a035-a60de93ed52e', 'dt': '2020-06-24T09:58:12Z', 'domain': 'zh.wikipedia.org', 'stream': 'mediawiki.recentchange', 'topic': 'eqiad.mediawiki.recentchange', 'partition': 0, 'offset': 2512145555}, 'id': 122959574, 'type': 'new', 'namespace': 3, 'title': 'User talk:MasterGaysha', 'comment': '{{uw-block3}}: [[WP:VOA|純粹破壞]]', 'timestamp': 1592992692, 'user': '蟲蟲飛', 'bot': False, 'minor': False, 'patrolled': True, 'length': {'new': 997}, 'revision': {'new': 60260248}, 'server_url': 'https://zh.wikipedia.org', 'server_name': 'zh.wikipedia.org', 'server_script_path': '/w', 'wiki': 'zhwiki', 'parsedcomment': '{{uw-block3}}: <a href="/wiki/Wikipedia:VOA" class="mw-redirect" title="Wikipedia:VOA">純粹破壞</a>'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=964, serialized_header_size=-1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-faec9385f32f> in <module>
#      11 consumer.subscribe(['wiki-changes']) #kafka topic
#      12
# ---> 13 for message in consumer:
#      14     print("**************************************")
#      15     print("**************************************")
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in __next__(self)
#    1190             return self.next_v1()
#    1191         else:
# -> 1192             return self.next_v2()
#    1193
#    1194     def next_v2(self):
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in next_v2(self)
#    1198                 self._iterator = self._message_generator_v2()
#    1199             try:
# -> 1200                 return next(self._iterator)
#    1201             except StopIteration:
#    1202                 self._iterator = None
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1113     def _message_generator_v2(self):
#    1114         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1115         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1116         for tp, records in six.iteritems(record_map):
#    1117             # Generators are stateful, and it is possible that the tp / records
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     652         remaining = timeout_ms
#     653         while True:
# --> 654             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     655             if records:
#     656                 return records
#
# /opt/conda/lib/python3.7/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     699
#     700         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 701         self._client.poll(timeout_ms=timeout_ms)
#     702         # after the long poll, we should check whether the group needs to rebalance
#     703         # prior to returning data so that the group can stabilize faster
#
# /opt/conda/lib/python3.7/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     598                     timeout = max(0, timeout)  # avoid negative timeouts
#     599
# --> 600                 self._poll(timeout / 1000)
#     601
#     602             # called without the lock to avoid deadlock potential
#
# /opt/conda/lib/python3.7/site-packages/kafka/client_async.py in _poll(self, timeout)
#     630
#     631         start_select = time.time()
# --> 632         ready = self._selector.select(timeout)
#     633         end_select = time.time()
#     634         if self._sensors:
#
# /opt/conda/lib/python3.7/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:
